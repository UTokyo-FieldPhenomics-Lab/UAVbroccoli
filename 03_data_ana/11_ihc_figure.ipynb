# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import seaborn as sns

# %%
date20 = ["May 18, 2020", "May 20, 2020", "May 22, 2020", "May 25, 2020", "May 26, 2020", "May 28, 2020"]
v0 = [0.68723,0.76858,0.80417 ,0.77590 ,0.77825 ,0.83959]
v1 = [0.77324  ,0.82437 ,0.85059 ,0.83086,0.85393 ,0.87278]
v2 = [0.83015,0.84952,0.85643,0.84945,0.88291,0.87923]
v3 = [0.83334,0.85709,0.86184,0.85319,0.89588,0.88024]
v4 = [0.82714,0.85950 ,0.86447,0.85240,0.89685,0.88313]
v5 = [0.83729 ,0.86106,0.86865,0.85026,0.89969, 0.88318]

date21 = ["May 12, 2021","May 14, 2021","May 15, 2021","May 19, 2021","May 20, 2021","May 26, 2021"]

v421 = [0.43485,0.75978,0.77781,0.88634,0.90226,0.84515]
v521 = [0.82218,0.87721,0.91228,0.91768,0.93479,0.94214]

v0avg = 0.74854
v1avg = 0.81180
v2avg = 0.85795
v3avg = 0.86360
v4avg = 0.86391
v5avg = 0.86669

v421avg = 0.79554
v521avg = 0.90105

# %%
iou20 = np.asarray([v0, v1, v2, v3, v4, v5])
iou20
# Out:
# array([[0.68723, 0.76858, 0.80417, 0.7759 , 0.77825, 0.83959],
#        [0.77324, 0.82437, 0.85059, 0.83086, 0.85393, 0.87278],
#        [0.83015, 0.84952, 0.85643, 0.84945, 0.88291, 0.87923],
#        [0.83334, 0.85709, 0.86184, 0.85319, 0.89588, 0.88024],
#        [0.82714, 0.8595 , 0.86447, 0.8524 , 0.89685, 0.88313],
#        [0.83729, 0.86106, 0.86865, 0.85026, 0.89969, 0.88318]])

# %%
iou21 = np.asarray([v421, v521])
iou21
# Out:
# array([[0.43485, 0.75978, 0.77781, 0.88634, 0.90226, 0.84515],
#        [0.82218, 0.87721, 0.91228, 0.91768, 0.93479, 0.94214]])

# %%
palette = sns.color_palette("Spectral", n_colors=5)
palette.insert(0, "k")
palette
# Out:
# ['k',
#  (0.9139561707035756, 0.36239907727797, 0.27935409457900806),
#  (0.9934640522875817, 0.7477124183006535, 0.4352941176470587),
#  (0.998077662437524, 0.9992310649750096, 0.7460207612456747),
#  (0.7477124183006538, 0.8980392156862746, 0.6274509803921569),
#  (0.3280276816608997, 0.6805074971164936, 0.6802768166089965)]

# %%
# colors = [(224, 241, 231), (168, 198, 188), ( 89, 137, 123), (71, 98, 91), (29, 45, 41)]
colors = ["#E0F1E7", "#A8C6BC", "#59897B", "#47625B", "#1D2D29"]
palette = sns.color_palette(colors)
palette
# Out:
# [(0.8784313725490196, 0.9450980392156862, 0.9058823529411765),
#  (0.6588235294117647, 0.7764705882352941, 0.7372549019607844),
#  (0.34901960784313724, 0.5372549019607843, 0.4823529411764706),
#  (0.2784313725490196, 0.3843137254901961, 0.3568627450980392),
#  (0.11372549019607843, 0.17647058823529413, 0.1607843137254902)]

# %%
legendict={'size': 20, 'weight':'bold'}
label_font = {'size': 20, 'weight':'bold'}
text_font = {"size":20}
linewidth = 2
markersize = 30
size = 30

sns.set_theme(style="ticks")

fig = plt.figure(figsize=(12,6))

ax1 = fig.add_subplot(121)

x = [18, 20, 22, 25, 26, 28]

# average line alpha
xx = 0.8
ax1.axhline(v0avg, xmin=0.07, xmax=0.93, linestyle='--', linewidth=linewidth, color=palette[0],alpha = xx)
ax1.axhline(v1avg, xmin=0.07, xmax=0.93, linestyle='--', linewidth=linewidth, color=palette[1],alpha = xx)
ax1.axhline(v2avg, xmin=0.07, xmax=0.93, linestyle='--', linewidth=linewidth, color=palette[2],alpha = xx)
ax1.axhline(v3avg, xmin=0.07, xmax=0.93, linestyle='--', linewidth=linewidth, color=palette[3],alpha = xx)
ax1.axhline(v4avg, xmin=0.07, xmax=0.93, linestyle='--', linewidth=linewidth, color=palette[4],alpha = xx)
ax1.axhline(v5avg, xmin=0.07, xmax=0.93, linestyle='--', linewidth=linewidth, color=palette[5],alpha = xx)

# ax1.plot(x, v0, marker='*', label='baseline', linewidth=linewidth,markersize=markersize, color=palette[0])
# ax1.plot(x, v1, marker='<', label='1st iteration', linewidth=linewidth,markersize=markersize, color=palette[1])
# ax1.plot(x, v2, marker='s', label='2nd iteration', linewidth=linewidth,markersize=markersize, color=palette[2])
# ax1.plot(x, v3, marker='>', label='3rd iteration', linewidth=linewidth,markersize=markersize, color=palette[3])
# ax1.plot(x, v4, marker='.', label='4th iteration', linewidth=linewidth,markersize=markersize, color=palette[6])
# ax1.plot(x, v5, marker='o', label='5th iteration', linewidth=linewidth,markersize=markersize, color=palette[3])

ax1.plot(x, v0, label='baseline', linewidth=linewidth,markersize=markersize, color=palette[0])
ax1.plot(x, v1, label='1st iteration', linewidth=linewidth,markersize=markersize, color=palette[1])
ax1.plot(x, v2, label='2nd iteration', linewidth=linewidth,markersize=markersize, color=palette[2])
ax1.plot(x, v3, label='3rd iteration', linewidth=linewidth,markersize=markersize, color=palette[3])
ax1.plot(x, v4, label='4th iteration', linewidth=linewidth,markersize=markersize, color=palette[4])
ax1.plot(x, v5, label='5th iteration', linewidth=linewidth,markersize=markersize, color=palette[5])

ax1.set_xticks([18, 20, 22, 25, 26.5, 28])
ax1.set_xticklabels(date20, fontsize=20)
ax1.set_yticks([0.6, 0.7, 0.8, 0.9])
ax1.set_yticklabels(["60", "70", "80", "90"], fontsize=20)

# for legend
ax1.plot([-1000, -1200], [0.77, 0.77], linewidth=linewidth, linestyle='--', label='average', color=palette[0])
ax1.set_xlim(17, 29)
ax1.set_ylim(0.68, 0.91)
ax1.set_xlabel("May 2020", fontdict=label_font)

ax1.text(23, 0.69, "(use 2021 data for 5th iteration)", fontdict=text_font, va='center', ha='center')

###############################
x = [12, 14, 15, 19, 20, 26]
ax2 = fig.add_subplot(122)
ax2.axhline(v421avg, xmin=0.07, xmax=0.93, linestyle='--', linewidth=linewidth, color=palette[4])
ax2.axhline(v521avg, xmin=0.07, xmax=0.93, linestyle='--', linewidth=linewidth, color=palette[5])

ax2.plot(x, v421, linewidth=linewidth,markersize=markersize, color=palette[4])
ax2.plot(x, v521,  linewidth=linewidth,markersize=markersize, color=palette[5])

ax2.set_xticks(x)
ax2.set_xticklabels(date21, fontsize=20)
ax2.set_yticks([0.4, 0.5, 0.6, 0.7, 0.8, 0.9])
ax2.set_yticklabels(["40", "50", "60", "70", "80", "90"], fontsize=20)

ax2.set_xlim(10, 28)
ax2.set_ylim(0.39, 0.95)
ax2.set_xlabel("May 2021", fontdict=label_font)

ax2.text(19, 0.415, "(4th iteration as baseline)", fontdict=text_font, va='center', ha='center')

handles, labels = [(a + b) for a, b in zip(ax1.get_legend_handles_labels(), ax2.get_legend_handles_labels())]
fig.legend(handles, labels, loc='lower right', fontsize=20, ncol=1, bbox_to_anchor=(0.98, 0.19))

#ax3 = fig.add_subplot(111, frameon=False)
# hide tick and tick label of the big axis
#plt.tick_params(labelcolor='none', which='both', top=False, bottom=False, left=False, right=False)
# plt.xlabel('Flight date', fontdict=label_font)
#ax1.set_ylabel("Mean IoU (%)", fontdict=label_font)
plt.tight_layout()
plt.show()

# %%
palette = sns.color_palette("Spectral", n_colors=7)
palette.remove(palette[2])
palette.remove(palette[2])
palette.insert(0, "k")
palette
# Out:
# ['k',
#  (0.8662821991541715, 0.2901191849288735, 0.2978085351787774),
#  (0.9748558246828143, 0.5574009996155325, 0.32272202998846594),
#  (0.8384467512495197, 0.9349480968858133, 0.6089965397923875),
#  (0.5273356401384084, 0.8106113033448674, 0.6452133794694349),
#  (0.24006151480199925, 0.58239138792772, 0.7208765859284891)]

# %%
legendict={'size': 30, 'weight':'bold'}
label_font = {'size': 30, 'weight':'bold'}
text_font = {"size":30}
linewidth = 2
markersize = 5
size = 30

sns.set_theme(style="whitegrid")

fig = plt.figure(figsize=(12,6))

ax1 = fig.add_subplot(111)


xlab = ["base", "1st", "2nd", "3rd", "4th\n(2021 base)", "5th"]

for i, d in enumerate(date20):
    ax1.plot([1, 2, 3, 4, 4.87, 5.87], iou20[:,i], "^--", label=d, linewidth=linewidth,markersize=markersize, color=palette[i], alpha=0.5)
    
#ax1.plot(x, [v0avg, v1avg, v2avg, v3avg, v4avg, v5avg], '+', label="2020 mean", c="k", markersize=10)
ax1.boxplot([v0, v1, v2, v3, v4, v5],
            vert=True,  # vertical box alignment
            positions=[1,2,3,4,4.87,5.87],  showfliers=False, widths=0.2) 


for j, d in enumerate(date21):
    ax1.plot([5.12, 6.12], iou21[:,j], "o:", label=d, linewidth=linewidth, markersize=markersize, color=palette[j], alpha=0.5)

ax1.boxplot([v421, v521],
            vert=True,  # vertical box alignment
            positions=[5.12,6.12], widths=0.2) 

ax1.set_xticks([1,2,3,4,5,6])
ax1.set_xticklabels(xlab, fontsize=20)

ax1.set_ylim(0.40, 0.95)
ax1.set_yticks([0.4, 0.5, 0.6, 0.7, 0.8, 0.9])
ax1.set_yticklabels(["40", "50", "60", "70", "80", "90"], fontsize=20)

ax1.set_xlabel("Iteration", fontdict=label_font)

ax1.grid(axis="x")

ax1.set_ylabel("Mean IoU (%)", fontdict=label_font)

plt.legend(ncol=2, fontsize=15)
plt.show()

# %%
legendict={'size': 30, 'weight':'bold'}
label_font = {'size': 30, 'weight':'bold'}
text_font = {"size":30}
linewidth = 2
markersize = 5
size = 30

sns.set_theme(style="whitegrid")

fig = plt.figure(figsize=(12,6))

ax1 = fig.add_subplot(111)


xlab = ["base", "1st", "2nd", "3rd", "4th\n(2021 base)", "5th"]

bplot1 = ax1.boxplot([v0, v1, v2, v3, v4, v5],
            vert=True,  # vertical box alignment
            patch_artist=True,
            positions=[1,2,3,4,4.87,5.87], widths=0.2) 

for patch in bplot1['boxes']:
    patch.set_facecolor("lightblue")

bplot2 = ax1.boxplot([v421, v521],
            vert=True,  # vertical box alignment
            patch_artist=True,
            positions=[5.12,6.12], widths=0.2) 

for patch in bplot2['boxes']:
    patch.set_facecolor("lightgreen")


ax1.set_xticks([1,2,3,4,5,6])
ax1.set_xticklabels(xlab, fontsize=20)

ax1.set_ylim(0.40, 0.95)
ax1.set_yticks([0.4, 0.5, 0.6, 0.7, 0.8, 0.9])
ax1.set_yticklabels(["40", "50", "60", "70", "80", "90"], fontsize=20)

ax1.set_xlabel("Iteration", fontdict=label_font)

ax1.set_ylabel("Mean IoU (%)", fontdict=label_font)

ax1.grid(axis="x")



#plt.legend(ncol=2, fontsize=15)
plt.show()

# %%
legendict={'size': 30, 'weight':'bold'}
label_font = {'size': 30, 'weight':'bold'}
text_font = {"size":30}
linewidth = 2
markersize = 5
size = 30

sns.set_theme(style="whitegrid")

fig = plt.figure(figsize=(12,6))

ax1 = fig.add_subplot(111)


xlab = ["base", "1st", "2nd", "3rd", "4th\n(2021 base)", "5th"]
    
bplot1 = ax1.boxplot([v0, v1, v2, v3, v4, v5],
            vert=True,  # vertical box alignment
            patch_artist=True,
            showfliers=False,
            positions=[1,2,3,4,4.87,5.87], widths=0.2) 

for patch in bplot1['boxes']:
    patch.set_facecolor("lightblue")

for i, d in enumerate(date20):
    ax1.plot([1, 2, 3, 4, 4.87, 5.87], iou20[:,i], "o--", label=d, linewidth=linewidth,markersize=markersize, color=palette[i], alpha=0.5)

    
# ========================================
bplot2 = ax1.boxplot([v421, v521],
            vert=True,  # vertical box alignment
            patch_artist=True,
            showfliers=False,
            positions=[5.12,6.12], widths=0.2) 

for patch in bplot2['boxes']:
    patch.set_facecolor("lightgreen")

    
for j, d in enumerate(date21):
    ax1.plot([5.12, 6.12], iou21[:,j], "o:", label=d, linewidth=linewidth, markersize=markersize, color=palette[j], alpha=0.5)


ax1.set_xticks([1,2,3,4,5,6])
ax1.set_xticklabels(xlab, fontsize=20)

ax1.set_ylim(0.40, 0.95)
ax1.set_yticks([0.4, 0.5, 0.6, 0.7, 0.8, 0.9])
ax1.set_yticklabels(["40", "50", "60", "70", "80", "90"], fontsize=20)

ax1.set_xlabel("Iteration", fontdict=label_font)

ax1.grid(axis="x")

ax1.set_ylabel("Mean IoU (%)", fontdict=label_font)

plt.legend(ncol=2, fontsize=15)
plt.show()

# %%
date20 = ["May 18", "May 20", "May 22", "May 25", "May 26", "May 28"]
date21 = ["May 12", "May 14", "May 15", "May 19", "May 20", "May 26"]

legendict={'size': 30, 'weight':'bold'}
label_font = {'size': 30, 'weight':'bold'}
text_font = {"size":30}
medianprops = dict(linestyle='-', linewidth=1, color='k')
linewidth = 2
markersize = 5
size = 30

sns.set_theme(style="ticks")

fig, ax = plt.subplots(2,1, figsize=(12,6), sharex=True)

ax1, ax2 = ax

xlab = ["base", "1st", "2nd", "3rd", "4th", "5th"]

ax1.text(3.5, 0.75, "2020", ha="center", va="center", fontdict={"size":70, "weight":"bold", "alpha":0.1})
    
bplot1 = ax1.boxplot([v0, v1, v2, v3, v4, v5],
            vert=True,  # vertical box alignment
            showfliers=False,
            positions=[1,2,3,4,5,6], widths=0.2, 
            medianprops=medianprops) 

for i, d in enumerate(date20):
    ax1.plot([1, 2, 3, 4, 5, 6], iou20[:,i], "o--", label=d, linewidth=linewidth,markersize=markersize, color=palette[i], alpha=0.5)
    
#ax1.set_xticks([1,2,3,4,5,6])
#ax1.set_xticklabels(xlab, fontsize=20)

ax1.set_ylim(0.65, 0.95)
ax1.set_yticks([0.7, 0.8, 0.9])
ax1.set_yticklabels(["70", "80", "90"], fontsize=30)

ax1.grid(axis="y")

ax1.legend(ncol=1, fontsize=17, bbox_to_anchor=(1.01, 1), loc='upper left')

# ========================================
ax2.text(3.5, 0.6, "2021", ha="center", va="center", fontdict={"size":70, "weight":"bold", "alpha":0.1})

bplot2 = ax2.boxplot([v421, v521],
            vert=True,  # vertical box alignment
            showfliers=False,
            positions=[5,6], 
            widths=0.2,
            medianprops=medianprops) 
    
for j, d in enumerate(date21):
    ax2.plot([5, 6], iou21[:,j], "o--", label=d, linewidth=linewidth, markersize=markersize, color=palette[j], alpha=0.5)


ax2.set_xticks([1,2,3,4,5,6])
ax2.set_xticklabels(xlab, fontsize=30)

ax2.set_xlim(0.5, 6.5)

ax2.set_ylim(0.4, 1)
ax2.set_yticks([0.4, 0.5, 0.6, 0.7, 0.8, 0.9, 1])
ax2.set_yticklabels(["40", "50", "60", "70", "80", "90", "100"], fontsize=30)

ax2.set_xlabel("Iteration", fontdict=label_font)

ax2.grid(axis="y")

#plt.set_ylabel("Mean IoU (%)", fontdict=label_font)

ax2.legend(ncol=1, fontsize=17, bbox_to_anchor=(1.01, 1), loc='upper left')

plt.tight_layout()

plt.show()

# %%
blo
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1fafb35bd48>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1faf77a0408>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1fafb35b2c8>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x1fafaa4fa08>,
# ...
#  'fliers': [],
#  'means': []}

# %%
legendict={'size': 30, 'weight':'bold'}
label_font = {'size': 30, 'weight':'bold'}
linewidth = 6
markersize = 30
size = 30


sns.set_theme(style="white")

fig = plt.figure(figsize=(12,8))

ax1 = fig.add_subplot(121)

x = np.array([0, 1, 2, 3, 4, 5])

# average alpha
xx = 0.8


total_width, n = 0.8, 6
width = total_width / n
x = x - (total_width - width) / 2

ax1.bar(x, v0, label='baseline', width=width, color=palette[0])
ax1.bar(x+width, v1, label='1st iteration', width=width, color=palette[1])
ax1.bar(x+2*width, v2, label='2nd iteration', width=width, color=palette[2])
ax1.bar(x+3*width, v3, label='3rd iteration', width=width, color=palette[3])
ax1.bar(x+4*width, v4, label='4th iteration', width=width, color=palette[4], alpha = 0.5)
ax1.bar(x+5*width, v5, label='5th iteration', width=width, color=palette[4])

ax1.set_xticks([0, 1, 2, 3, 4, 5])
ax1.set_xticklabels(["5.18", "5.20", "5.22", "5.25", "5.26", "5.28"], fontsize=20)
ax1.set_yticks([0.5, 0.6, 0.7, 0.8, 0.9])
ax1.set_yticklabels(["50", "60", "70", "80", "90"], fontsize=20)

# for legend
ax1.plot([-1000, -1200], [0.77, 0.77], linewidth=linewidth, linestyle='--', label='average', color=palette[4])
ax1.set_xlim(-1, 6)
ax1.set_ylim(0.65, 0.92)
ax1.set_xlabel("2020", fontdict=label_font)
# ax1.legend(prop=legendict, ncol=2)

###############################
ax2 = fig.add_subplot(122)
ax2.axhline(v421avg, xmin=0.07, xmax=0.93, linestyle='--', linewidth=linewidth, color=palette[4],alpha = 0.5)
ax2.axhline(v521avg, xmin=0.07, xmax=0.93, linestyle='--', linewidth=linewidth, color=palette[4],alpha = xx)

# ax2.plot(x, v421, marker='.', linewidth=linewidth,markersize=markersize, color=palette[6])
# ax2.plot(x, v521, marker='o',  linewidth=linewidth,markersize=markersize, color=palette[3])

ax2.plot(x, v421, linewidth=linewidth,markersize=markersize, color=palette[4],alpha = 0.5)
ax2.plot(x, v521,  linewidth=linewidth,markersize=markersize, color=palette[4])

ax2.set_xticks([18, 20, 22, 25, 26.5, 28])
ax2.set_xticklabels(["5.18", "5.20", "5.22", "5.25", "5.26", "5.28"], fontsize=20)
ax2.set_yticks([])
# ax2.set_yticklabels(["50", "60", "70", "80", "90"], fontsize=20)

ax2.set_xlim(17, 29)
ax2.set_ylim(0.65, 0.95)
ax2.set_xlabel("2021", fontdict=label_font)
handles, labels = [(a + b) for a, b in zip(ax1.get_legend_handles_labels(), ax2.get_legend_handles_labels())]
fig.legend(handles, labels, loc='lower right', fontsize=20, ncol=1, bbox_to_anchor=(0.98, 0.16))

ax3 = fig.add_subplot(111, frameon=False)
# hide tick and tick label of the big axis
plt.tick_params(labelcolor='none', which='both', top=False, bottom=False, left=False, right=False)
# plt.xlabel('Flight date', fontdict=label_font)
plt.ylabel("Mean IoU (%)", fontdict=label_font)
plt.tight_layout()
plt.show()

# %%
t0 = [100.8, 166.1, 420.4, 649.21, 1085.2]
iou0 = [0.74854, 0.81180, 0.84135, 0.84991, 0.85247]

# %%
sns.set_theme(style="whitegrid")

fig = plt.figure(figsize=(12,5))

ax = fig.add_subplot(111)

ax.plot(t0, [item*100 for item in iou0], linestyle='--', color=palette[7])
ax.plot([1814, 4126.39, 7085.4], [76.3, 79.0, 79.5], linestyle='--', color=palette[7])


ax.scatter(t0[0], iou0[0]*100, s=400, color=palette[0])
ax.scatter(t0[1], iou0[1]*100, s=800, color=palette[1])
ax.scatter(t0[2], iou0[2]*100, s=1000, color=palette[2])
ax.scatter(t0[3], iou0[3]*100, s=1200, color=palette[3])
ax.scatter(t0[4], iou0[4]*100, s=1500, color=palette[6])

ax.scatter(1814, 76.3, s=800, color=palette[2], marker='^')
ax.scatter(4126.39, 79.0, s=1200, color=palette[3], marker='^')
ax.scatter(7085.4, 79.55, s=1500, color=palette[6], marker='^')

# for legend
ax.scatter(-1000, 77, s=1000, color=palette[7], label='Ours')
ax.scatter(-1000, 77, s=1000, color=palette[7], marker='^', label='Mask R-CNN')

plt.xlim(-50, 7300)
plt.ylim(74, 87)
# plt.xscale('log')

plt.xlabel("Train cost time (min)", fontdict=label_font)
plt.ylabel("Mean IoU (%)", fontdict=label_font)
ticks = [100, 600, 2000, 4000, 7300]
labels = [1, 10, 30, 60, 120]

plt.xticks(ticks, labels, fontproperties='Times New Roman', size=size)
# plt.xticks(fontproperties='Times New Roman', size=size)
plt.yticks([76, 78, 80, 82, 84, 86], ["76", "78", "80", "82", "84", "86"], fontproperties='Times New Roman', size=size)

plt.legend(prop=legendict, loc = 'upper right')
plt.show()
