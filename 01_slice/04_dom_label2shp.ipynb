# %%
import sys
sys.path.insert(0, f'D:/OneDrive/Program/GitHub/EasyIDP')

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
from easyric.objects import Pix4D
from easyric.io import shp, geotiff, plot
from easyric.calculate import geo2raw, geo2tiff

from easyric.caas_lite import TiffSpliter

# %%
project_name = 'broccoli_tanashi_5_20200528_P4M_10m_before'
project_path = f"Z:/共享云端硬盘/broccoliProject/tanashi_broccoli2020_RGB_AP/{project_name}"
raw_img_folder=f"Z:/共享云端硬盘/broccoliProject/rgb_raw/{project_name}"
label_folder = f"Z:/共享云端硬盘/broccoliProject/pred_bbox_nms_0.3/{project_name}/labels"
param_folder = f"{project_path}/params"

# %%
p4d = Pix4D(project_path=project_path, 
            raw_img_path=raw_img_folder, 
            project_name=project_name,
            param_folder=param_folder)
# Out:
# [Init][Pix4D] No ply given, however find 'broccoli_tanashi_5_20200528_P4M_10m_before_group1_densified_point_cloud.ply' at current project folder
# [Init][Pix4D] No dom given, however find 'broccoli_tanashi_5_20200528_P4M_10m_before_transparent_mosaic_group1.tif' at current project folder
# [Init][Pix4D] No dsm given, however find 'broccoli_tanashi_5_20200528_P4M_10m_before_dsm.tif' at current project folder
# [io][geotiff][GeoCorrd] Comprehense [* 34737 geo_ascii_params (30s) b'WGS 84 / UTM zone 54N|WGS 84|'] to geotiff coordinate tag [WGS 84 / UTM zone 54N]
# [io][geotiff][GeoCorrd] Comprehense [* 34737 geo_ascii_params (30s) b'WGS 84 / UTM zone 54N|WGS 84|'] to geotiff coordinate tag [WGS 84 / UTM zone 54N]

# %%
grid_len = 1300
buffer_len = 200
ts = TiffSpliter(tif_path=p4d.dom_file, grid_h=grid_len, grid_w=grid_len, grid_buffer=buffer_len)

# %%
from dom_label2raw import read_label

# %%
keep_bbox, rm_bbox = read_label(project_name)
# Out:
# [Init][Pix4D] No ply given, however find 'broccoli_tanashi_5_20200528_P4M_10m_before_group1_densified_point_cloud.ply' at current project folder
# [Init][Pix4D] No dom given, however find 'broccoli_tanashi_5_20200528_P4M_10m_before_transparent_mosaic_group1.tif' at current project folder
# [Init][Pix4D] No dsm given, however find 'broccoli_tanashi_5_20200528_P4M_10m_before_dsm.tif' at current project folder
# [io][geotiff][GeoCorrd] Comprehense [* 34737 geo_ascii_params (30s) b'WGS 84 / UTM zone 54N|WGS 84|'] to geotiff coordinate tag [WGS 84 / UTM zone 54N]
# [io][geotiff][GeoCorrd] Comprehense [* 34737 geo_ascii_params (30s) b'WGS 84 / UTM zone 54N|WGS 84|'] to geotiff coordinate tag [WGS 84 / UTM zone 54N]
# ======broccoli_tanashi_5_20200528_P4M_10m_before======
# reading grid_x04_y12.txt

# %%
keep_bbox
# Out:
#       offset_x  offset_y   xc    yc   w   h    thresh   x0   x1    y0  ...  \
# 5        16900      7800   16   691  32  48  0.719238    0   32   667  ...
# 7        16900      7800  319   984  64  53  0.739258  287  351   958  ...
# 9        16900      7800  191   375  70  62  0.752441  156  226   344  ...
# 10       16900      7800  292   858  60  52  0.755371  262  322   832  ...
# 11       16900      7800  119  1201  40  44  0.756836   99  139  1179  ...
# ...        ...       ...  ...   ...  ..  ..       ...  ...  ...   ...  ...
# 9930      5200     15600  690   694  69  66  0.806641  655  724   661  ...
# 9931      5200     15600  140  1012  71  61  0.809570  104  175   982  ...
# 9932      5200     15600  222  1398  55  46  0.811523  195  250  1375  ...
# 9933      5200     15600  588   219  71  65  0.816406  553  624   186  ...
# 9934      5200     15600   88   768  70  63  0.822266   53  123   736  ...
#
#       x1_dom  y0_dom  y1_dom         xc_geo        yc_geo         x0_geo  \
# 5      16932    8467    8515  368100.201195  3.956048e+06  368100.158155
# 7      17251    8758    8811  368101.016265  3.956048e+06  368100.930185
# 9      17126    8144    8206  368100.671945  3.956049e+06  368100.577795
# 10     17222    8632    8684  368100.943635  3.956048e+06  368100.862935
# 11     17039    8979    9023  368100.478265  3.956047e+06  368100.424465
# ...      ...     ...     ...            ...           ...            ...
# 9930    5924   16261   16327  368070.541255  3.956027e+06  368070.447105
# 9931    5375   16582   16643  368069.061755  3.956026e+06  368068.964915
# 9932    5450   16975   17021  368069.282335  3.956025e+06  368069.209705
# 9933    5824   15786   15851  368070.266875  3.956029e+06  368070.172725
# 9934    5323   16336   16399  368068.921875  3.956027e+06  368068.827725
#
#             y0_geo         x1_geo        y1_geo  keep
# 5     3.956048e+06  368100.244235  3.956048e+06  True
# 7     3.956048e+06  368101.102345  3.956047e+06  True
# 9     3.956049e+06  368100.766095  3.956049e+06  True
# 10    3.956048e+06  368101.024335  3.956048e+06  True
# 11    3.956047e+06  368100.532065  3.956047e+06  True
# ...            ...            ...           ...   ...
# 9930  3.956027e+06  368070.632715  3.956027e+06  True
# 9931  3.956027e+06  368069.155905  3.956026e+06  True
# 9932  3.956025e+06  368069.357655  3.956025e+06  True
# 9933  3.956029e+06  368070.363715  3.956029e+06  True
# 9934  3.956027e+06  368069.016025  3.956027e+06  True
#
# [7078 rows x 24 columns]

# %%
rm_bbox
# Out:
#       offset_x  offset_y   xc    yc   w   h    thresh   x0   x1    y0  ...  \
# 0        16900      7800    7   574  14  53  0.424072    0   14   548  ...
# 1        16900      7800  162   140  53  82  0.642090  135  188    99  ...
# 2        16900      7800  435  1463  53  40  0.646973  409  462  1443  ...
# 3        16900      7800  114    21  68  39  0.687988   80  148     1  ...
# 4        16900      7800   82  1092  57  48  0.712891   54  111  1068  ...
# ...        ...       ...  ...   ...  ..  ..       ...  ...  ...   ...  ...
# 9908      5200     15600  565    84  68  57  0.719727  531  599    56  ...
# 9912      5200     15600   32   515  64  72  0.744629    0   64   479  ...
# 9916      5200     15600  171  1139  61  64  0.770996  141  202  1107  ...
# 9922      5200     15600  204   128  62  70  0.789062  173  235    93  ...
# 9926      5200     15600   58   639  64  59  0.798340   26   90   610  ...
#
#       x1_dom  y0_dom  y1_dom         xc_geo        yc_geo         x0_geo  \
# 0      16914    8348    8401  368100.176985  3.956049e+06  368100.158155
# 1      17088    7899    7981  368100.593935  3.956050e+06  368100.521305
# 2      17362    9243    9283  368101.328305  3.956046e+06  368101.258365
# 3      17048    7801    7840  368100.464815  3.956050e+06  368100.373355
# 4      17011    8868    8916  368100.378735  3.956047e+06  368100.303415
# ...      ...     ...     ...            ...           ...            ...
# 9908    5799   15656   15713  368070.205005  3.956029e+06  368070.113545
# 9912    5264   16079   16151  368068.771235  3.956028e+06  368068.685155
# 9916    5402   16707   16771  368069.145145  3.956026e+06  368069.064445
# 9922    5435   15693   15763  368069.233915  3.956029e+06  368069.150525
# 9926    5290   16210   16269  368068.841175  3.956027e+06  368068.755095
#
#             y0_geo         x1_geo        y1_geo   keep
# 0     3.956049e+06  368100.195815  3.956049e+06  False
# 1     3.956050e+06  368100.663875  3.956050e+06  False
# 2     3.956046e+06  368101.400935  3.956046e+06  False
# 3     3.956050e+06  368100.556275  3.956050e+06  False
# 4     3.956047e+06  368100.456745  3.956047e+06  False
# ...            ...            ...           ...    ...
# 9908  3.956029e+06  368070.296465  3.956029e+06  False
# 9912  3.956028e+06  368068.857315  3.956028e+06  False
# 9916  3.956026e+06  368069.228535  3.956026e+06  False
# 9922  3.956029e+06  368069.317305  3.956029e+06  False
# 9926  3.956028e+06  368068.927255  3.956027e+06  False
#
# [2857 rows x 24 columns]

# %%
import shapefile

# %%
with shapefile.Writer('out/rm_bbox') as shp:
    shp.field('name', 'C')
    for i in range(len(rm_bbox)):
        x0 = rm_bbox.x0_geo.iloc[i]
        y0 = rm_bbox.y0_geo.iloc[i]
        x1 = rm_bbox.x1_geo.iloc[i]
        y1 = rm_bbox.y1_geo.iloc[i]
        
        coord = [[x0, y0],[x1, y0],[x1, y1],[x0, y1],[x0, y0]]
        shp.poly([coord])
        shp.record(str(i))

# %%
def save_shp(bbox, shp_path):
    with shapefile.Writer(shp_path) as shp:
        shp.field('name', 'C')
        for i in range(len(bbox)):
            x0 = bbox.x0_geo.iloc[i]
            y0 = bbox.y0_geo.iloc[i]
            x1 = bbox.x1_geo.iloc[i]
            y1 = bbox.y1_geo.iloc[i]

            coord = [[x0, y0],[x1, y0],[x1, y1],[x0, y1],[x0, y0]]
            shp.poly([coord])
            shp.record(str(i))

# %%
save_shp(keep_bbox, 'out/keep_bbox')
