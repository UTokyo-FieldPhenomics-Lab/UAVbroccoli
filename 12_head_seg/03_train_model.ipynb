# %%
from bisenet import engine
import config
from config import *
from utils import *

from pycocotools.coco import COCO
import json

# %% [markdown]
# ### 01 - Convert labelme json format to coco format

# %%
project_data_folder_path = Path(project_data_folder)
working_space_path = project_data_folder_path.joinpath(working_spacename)

annotation_path = working_space_path.joinpath('annotations', 'tbd')

# %%
@at_path(annotation_path)
def get_coco(annotation_path):
    # print(os.getcwd())
    annotation_path_entry = os.scandir(annotation_path)
    return labelme2coco(annotation_path_entry)

# %%
coco_json = get_coco(annotation_path)
with open(config.coco_path, 'w+') as f:
    f.write(json.dumps(coco_json))
# Out:
# Z:\hwang_Pro\data\2022_tanashi_broccoli\12_head_segment\annotations\tbd
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!

# %%
coco = COCO(config.coco_path)
# Out:
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!

# %% [markdown]
# ### 02 - Init bisenet engine

# %%
bisenet_engine = engine.bisenet_engine(config)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# d:\UAVbroccoli\12_head_seg\03_train_model.ipynb Cell 8 in <module>
# ----> <a href='vscode-notebook-cell:/d%3A/UAVbroccoli/12_head_seg/03_train_model.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> bisenet_engine = engine.bisenet_engine(config)
#
# File d:\UAVbroccoli\12_head_seg\bisenet\engine.py:58, in bisenet_engine.__init__(self, args)
#      55 self.classes = args.classes
#      56 self.n_classes = len(args.classes)
# ---> 58 self.batch_size = args.batch_size
#      59 self.lr = args.learning_rate
#      60 self.beta_1 = args.beta_1 # 0.5
#
# AttributeError: module 'config' has no attribute 'batch_size'

# %%
# Out:
# loading annotations into memory...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# d:\UAVbroccoli\12_head_seg\03_train_model.ipynb Cell 8 in <module>
#       <a href='vscode-notebook-cell:/d%3A/UAVbroccoli/12_head_seg/03_train_model.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> from pycocotools.coco import COCO
#       <a href='vscode-notebook-cell:/d%3A/UAVbroccoli/12_head_seg/03_train_model.ipynb#X13sZmlsZQ%3D%3D?line=1'>2</a> import json
# ----> <a href='vscode-notebook-cell:/d%3A/UAVbroccoli/12_head_seg/03_train_model.ipynb#X13sZmlsZQ%3D%3D?line=2'>3</a> COCO(json.dumps(coco_json))
#
# File c:\Users\ddgip\.conda\envs\uavb2\lib\site-packages\pycocotools\coco.py:84, in COCO.__init__(self, annotation_file)
#      82 print('loading annotations into memory...')
#      83 tic = time.time()
# ---> 84 dataset = json.load(open(annotation_file, 'r'))
#      85 assert type(dataset)==dict, 'annotation file format {} not supported'.format(type(dataset))
#      86 print('Done (t={:0.2f}s)'.format(time.time()- tic))
#
# FileNotFoundError: [Errno 2] No such file or directory: '{"info": {"year": 2023, "version": "5.0.1", "flags": {}, "date_created": "2023-04-21T08:13:02.149791+00:00"}, "images": [{"id": "364_DJI_0151.png", "width": 1000, "height": 1000, "file_name": "364_DJI_0151.png", "license": null, "flickr_url": null, "coco_url": null, "date_captured": null, "imagePath": "\\\\\\\\192.168.253.181\\\\dataNprocess\\\\hwang_Pro\\\\data\\\\2022_tanashi_broccoli\\\\12_head_segment\\\\broccoli_autumn21-20220331_0\\\\364_DJI_0151.png"}, {"id": "364_DJI_0158.png", "width": 1000, "height": 1000, "file_name": "364_DJI_0158.png", "license": null, "flickr_url": null, "coco_url": null, "date_captured": null, "imagePath": "\\\\\\\\192.168.253.181\\\\dataNprocess\\\\hwang_Pro\\\\data\\\\2022_tanashi_broccoli\\\\12_head_segment\\\\broccoli_autumn21-20220405_0\\\\364_DJI_0