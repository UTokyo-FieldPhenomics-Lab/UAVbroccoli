# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import seaborn as sns

from adjustText import adjust_text

# %%
palette = sns.color_palette()
palette
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#  (1.0, 0.4980392156862745, 0.054901960784313725),
#  (0.17254901960784313, 0.6274509803921569, 0.17254901960784313),
#  (0.8392156862745098, 0.15294117647058825, 0.1568627450980392),
#  (0.5803921568627451, 0.403921568627451, 0.7411764705882353),
#  (0.5490196078431373, 0.33725490196078434, 0.29411764705882354),
#  (0.8901960784313725, 0.4666666666666667, 0.7607843137254902),
#  (0.4980392156862745, 0.4980392156862745, 0.4980392156862745),
#  (0.7372549019607844, 0.7411764705882353, 0.13333333333333333),
#  (0.09019607843137255, 0.7450980392156863, 0.8117647058823529)]

# %%
# colors = [(224, 241, 231), (168, 198, 188), ( 89, 137, 123), (71, 98, 91), (29, 45, 41)]
colors = ["#E0F1E7", "#A8C6BC", "#59897B", "#47625B", "#1D2D29"]
palette = sns.color_palette(colors)
palette
# Out:
# [(0.8784313725490196, 0.9450980392156862, 0.9058823529411765),
#  (0.6588235294117647, 0.7764705882352941, 0.7372549019607844),
#  (0.34901960784313724, 0.5372549019607843, 0.4823529411764706),
#  (0.2784313725490196, 0.3843137254901961, 0.3568627450980392),
#  (0.11372549019607843, 0.17647058823529413, 0.1607843137254902)]

# %%
palette = sns.color_palette("Spectral", n_colors=5)
palette.insert(0, "k")
palette
# Out:
# ['k',
#  (0.9139561707035756, 0.36239907727797, 0.27935409457900806),
#  (0.9934640522875817, 0.7477124183006535, 0.4352941176470587),
#  (0.998077662437524, 0.9992310649750096, 0.7460207612456747),
#  (0.7477124183006538, 0.8980392156862746, 0.6274509803921569),
#  (0.3280276816608997, 0.6805074971164936, 0.6802768166089965)]

# %%
t0 = [100.8, 166.1, 420.4, 649.21, 1085.2, 1267.5]
iou0 = [0.77562, 0.83429, 0.85795, 0.86360, 0.86391, 0.86669]
iou1 = [0.7677,0.90105]

# %%
palette
# Out:
# ['k',
#  (0.9139561707035756, 0.36239907727797, 0.27935409457900806),
#  (0.9934640522875817, 0.7477124183006535, 0.4352941176470587),
#  (0.998077662437524, 0.9992310649750096, 0.7460207612456747),
#  (0.7477124183006538, 0.8980392156862746, 0.6274509803921569),
#  (0.3280276816608997, 0.6805074971164936, 0.6802768166089965)]

# %%
palette = sns.color_palette("Spectral", n_colors=7)
palette.remove(palette[2])
palette.remove(palette[2])
palette.insert(0, "k")
palette
# Out:
# ['k',
#  (0.8662821991541715, 0.2901191849288735, 0.2978085351787774),
#  (0.9748558246828143, 0.5574009996155325, 0.32272202998846594),
#  (0.8384467512495197, 0.9349480968858133, 0.6089965397923875),
#  (0.5273356401384084, 0.8106113033448674, 0.6452133794694349),
#  (0.24006151480199925, 0.58239138792772, 0.7208765859284891)]

# %%
sns.set_theme(style="whitegrid")

fig = plt.figure(figsize=(12,10))

ax = fig.add_subplot(121)

ax.plot(t0, [item*100 for item in iou0], linestyle='--', color=palette[0], alpha=0.5)
ax.plot([1814, 4126.39, 7085.4, 8399.4], [76.3, 79.0, 79.5, 80], linestyle='--', color=palette[0], alpha=0.5)


ax.scatter(t0[0], iou0[0]*100, s=400, color=palette[0])
ax.scatter(t0[1], iou0[1]*100, s=800, color=palette[1])
ax.scatter(t0[2], iou0[2]*100, s=1000, color=palette[2])
ax.scatter(t0[3], iou0[3]*100, s=1200, color=palette[3])
ax.scatter(t0[4], iou0[4]*100, s=1500, color=palette[4])
ax.scatter(t0[5], iou0[5]*100, s=1800, color=palette[5])



ax.scatter(1814, 76.3, s=800, color=palette[2], marker='^')
ax.scatter(4126.39, 79.0, s=1200, color=palette[3], marker='^')
ax.scatter(7085.4, 79.55, s=1500, color=palette[4], marker='^')
ax.scatter(8399.4, 80, s=1800, color=palette[5], marker='^')


# for legend
ax.scatter(-1000, 77, s=1000, color=palette[0], label='Ours')
ax.scatter(-1000, 77, s=1000, color=palette[0], marker='^', label='Mask R-CNN')

ax.set_xticks([])

# yticks = [76, 80, 84, 88, 90]
# ylabels = [str(item) for item in yticks]
yticks = [50, 60, 70, 80, 90]
ylabels = [str(item) for item in yticks]
ax.set_yticks(yticks)
ax.set_yticklabels(ylabels, fontsize=size)


ax.set_xlim(80, 1.1*1e4)
ax.set_xscale('log')
ax.set_ylim(54, 92)

################################
# sns.set_theme(style="whitegrid")

ax2 = fig.add_subplot(122)

ax2.scatter(t0[4], iou1[0]*100, s=1500, color=palette[4], facecolor='none', linewidth=3)
ax2.scatter(t0[5], iou1[1]*100, s=1800, color=palette[5], facecolor='none', linewidth=3)

ax2.scatter(7085.4, 57.2, s=1500, color=palette[4], marker='^', facecolor='none', linewidth=3)
ax2.scatter(8399.4, 70.5, s=1800, color=palette[5], marker='^', facecolor='none', linewidth=3)

ax2.plot(t0[4:], [item*100 for item in iou1], linestyle='--', color=palette[0], alpha=0.5)
ax2.plot([7085.4, 8399.4], [57.2, 70.5], linestyle='--', color=palette[0], alpha=0.5)
ax2.set_xticks([])
# ax2.set_xticklabels(labels, fontsize=size)
ax2.set_xlim(0.9 *1e3, 1e4)
ax2.set_xscale('log')


yticks = [50, 60, 70, 80, 90]
ylabels = [str(item) for item in yticks]
ax2.set_yticks(yticks)
ax2.set_yticklabels(ylabels, fontsize=0)

ax2.set_ylim(54, 92)

handles, labels = [(a + b) for a, b in zip(ax.get_legend_handles_labels(), ax2.get_legend_handles_labels())]
fig.legend(handles, labels, loc='upper right', fontsize=20, ncol=1, bbox_to_anchor=(0.98, 0.96))

# plt.xscale('log')
################################
# ax3 = fig.add_subplot(111, frameon=False)
# ax3.set_xlim(-50, 10000)
# ax3.set_ylim(74, 92)

# ticks = [100, 600, 1800, 3600, 7200, 10800]
# labels = [1, 10, 30, 60, 120, 180]
# ax3.set_xticks(ticks)
# ax3.set_xticklabels(labels, fontsize=size)
# hide tick and tick label of the big axis
# plt.tick_params(labelcolor='none', which='both', top=False, bottom=False, left=False, right=False)
# plt.xlabel('Flight date', fontdict=label_font)
# plt.ylabel("Mean IoU (%)", fontdict=label_font)
# plt.xlabel("Train cost time (min)", fontdict=label_font)


# plt.xticks(fontproperties='Times New Roman', size=size)


# plt.legend(prop=legendict, loc = 'upper right')
plt.tight_layout()
plt.show()

# %%
sns.set_theme(style="whitegrid")

fig = plt.figure(figsize=(12,10))

ax = fig.add_subplot(211)

ax.plot(t0, [item*100 for item in iou0], linestyle='--', color=palette[0], alpha=0.5)
ax.plot([1814, 4126.39, 7085.4, 8399.4], [76.3, 79.0, 79.5, 80], linestyle='--', color=palette[0], alpha=0.5)


ax.scatter(t0[0], iou0[0]*100, s=400, color=palette[0])
ax.scatter(t0[1], iou0[1]*100, s=800, color=palette[1])
ax.scatter(t0[2], iou0[2]*100, s=1000, color=palette[2])
ax.scatter(t0[3], iou0[3]*100, s=1200, color=palette[3])
ax.scatter(t0[4], iou0[4]*100, s=1500, color=palette[4])
ax.scatter(t0[5], iou0[5]*100, s=1800, color=palette[5])



ax.scatter(1814, 76.3, s=800, color=palette[2], marker='^')
ax.scatter(4126.39, 79.0, s=1200, color=palette[3], marker='^')
ax.scatter(7085.4, 79.55, s=1500, color=palette[4], marker='^')
ax.scatter(8399.4, 80, s=1800, color=palette[5], marker='^')


# for legend
ax.scatter(-1000, 77, s=1000, color=palette[0], label='Ours')
ax.scatter(-1000, 77, s=1000, color=palette[0], marker='^', label='Mask R-CNN')

ax.set_xticks([])

# yticks = [76, 80, 84, 88, 90]
# ylabels = [str(item) for item in yticks]
yticks = [50, 60, 70, 80, 90]
ylabels = [str(item) for item in yticks]
ax.set_yticks(yticks)
ax.set_yticklabels(ylabels, fontsize=size)


ax.set_xlim(80, 1.1*1e4)
ax.set_xscale('log')
ax.set_ylim(54, 92)

################################
# sns.set_theme(style="whitegrid")

ax2 = fig.add_subplot(212)

ax2.scatter(t0[4], iou1[0]*100, s=1500, color=palette[4], facecolor='none', linewidth=3)
ax2.scatter(t0[5], iou1[1]*100, s=1800, color=palette[5], facecolor='none', linewidth=3)

ax2.scatter(7085.4, 57.2, s=1500, color=palette[4], marker='^', facecolor='none', linewidth=3)
ax2.scatter(8399.4, 70.5, s=1800, color=palette[5], marker='^', facecolor='none', linewidth=3)

ax2.plot(t0[4:], [item*100 for item in iou1], linestyle='--', color=palette[0], alpha=0.5)
ax2.plot([7085.4, 8399.4], [57.2, 70.5], linestyle='--', color=palette[0], alpha=0.5)
ax2.set_xticks([])
# ax2.set_xticklabels(labels, fontsize=size)
ax2.set_xlim(0.9 *1e3, 1e4)
ax2.set_xscale('log')


yticks = [50, 60, 70, 80, 90]
ylabels = [str(item) for item in yticks]
ax2.set_yticks(yticks)
ax2.set_yticklabels(ylabels, fontsize=size)

ax2.set_ylim(54, 92)

handles, labels = [(a + b) for a, b in zip(ax.get_legend_handles_labels(), ax2.get_legend_handles_labels())]
fig.legend(handles, labels, loc='upper right', fontsize=20, ncol=1, bbox_to_anchor=(0.98, 0.96))

# plt.xscale('log')
################################
# ax3 = fig.add_subplot(111, frameon=False)
# ax3.set_xlim(-50, 10000)
# ax3.set_ylim(74, 92)

# ticks = [100, 600, 1800, 3600, 7200, 10800]
# labels = [1, 10, 30, 60, 120, 180]
# ax3.set_xticks(ticks)
# ax3.set_xticklabels(labels, fontsize=size)
# hide tick and tick label of the big axis
# plt.tick_params(labelcolor='none', which='both', top=False, bottom=False, left=False, right=False)
# plt.xlabel('Flight date', fontdict=label_font)
# plt.ylabel("Mean IoU (%)", fontdict=label_font)
# plt.xlabel("Train cost time (min)", fontdict=label_font)


# plt.xticks(fontproperties='Times New Roman', size=size)


# plt.legend(prop=legendict, loc = 'upper right')
plt.tight_layout()
plt.show()

# %%
legendict={'size': 20, 'weight':'bold'}
label_font = {'size': 30, 'weight':'bold'}
linewidth = 3
markersize = 30
size = 20

sns.set_theme(style="whitegrid")

fig = plt.figure(figsize=(12,14))

ax = fig.add_subplot(211)

ax.plot(t0, [item*100 for item in iou0], linestyle='--', color=palette[0], alpha=0.5)
ax.plot([1814, 4126.39, 7085.4, 8399.4], [76.3, 79.0, 79.5, 80], linestyle='--', color=palette[0], alpha=0.5)
ax.plot([7085.4, 8399.4], [57.2, 70.5], linestyle='-.', color=palette[0], alpha=0.5)

ax.scatter(t0[4], iou1[0]*100, s=1200, color=palette[4], marker='o', facecolor='none', linewidth=3)
ax.scatter(t0[5], iou1[1]*100, s=1400, color=palette[5], marker='o', facecolor='none', linewidth=3)

ax.plot(t0[4:], [item*100 for item in iou1], linestyle='-.', color=palette[0], alpha=0.5)

ax.scatter(t0[0], iou0[0]*100, s=400, color=palette[0], marker='o')
ax.scatter(t0[1], iou0[1]*100, s=600, color=palette[1], marker='o')
ax.scatter(t0[2], iou0[2]*100, s=800, color=palette[2], marker='o')
ax.scatter(t0[3], iou0[3]*100, s=1000, color=palette[3], marker='o')
ax.scatter(t0[4], iou0[4]*100, s=1200, color=palette[4], marker='o')
ax.scatter(t0[5], iou0[5]*100, s=1400, color=palette[5], marker='o')

ax.scatter(1814, 76.3, s=800, color=palette[2], marker='^')
ax.scatter(4126.39, 79.0, s=1000, color=palette[3], marker='^')
ax.scatter(7085.4, 79.55, s=1200, color=palette[4], marker='^')
ax.scatter(8399.4, 80, s=1400, color=palette[5], marker='^')

ax.scatter(7085.4, 57.2, s=1200, color=palette[4], marker='^', facecolor='none', linewidth=3)
ax.scatter(8399.4, 70.5, s=1400, color=palette[5], marker='^', facecolor='none', linewidth=3)

# for legend
ax.scatter(-1000, 77, s=700, color=palette[0], marker='s', label='baseline', alpha=0.8)
ax.scatter(-1000, 77, s=700, color=palette[1], marker='s', label='1st iteration', alpha=0.8)
ax.scatter(-1000, 77, s=700, color=palette[2], marker='s', label='2nd iteration', alpha=0.8)
ax.scatter(-1000, 77, s=700, color=palette[3], marker='s', label='3rd iteration', alpha=0.8)
ax.scatter(-1000, 77, s=700, color=palette[4], marker='s', label='4th iteration', alpha=0.8)
ax.scatter(-1000, 77, s=700, color=palette[5], marker='s', label='5th iteration', alpha=0.8)

ax.scatter(-1000, 77, s=700, color=palette[0], marker='o', label='Ours', alpha=0.5)
ax.scatter(-1000, 77, s=700, color=palette[0], marker='^', label='Mask R-CNN', alpha=0.5)

ticks = [100, 600, 1800, 3600, 7200, 10800]
labels = [1, 10, 30, 60, 120, 180]
# ax.set_xticks([])
# ax.set_xticklabels(labels, fontsize=size)

# yticks = [76, 80, 84, 88, 90]
# ylabels = [str(item) for item in yticks]
# ax.set_yticks(yticks)
# ax.set_yticklabels(ylabels, fontsize=size)

# plt.xscale('log')
ax.set_xlim(-100, 9000)
ax.set_ylim(50, 94)

plt.ylabel("Mean IoU (%)", fontdict=label_font)
plt.xlabel("Train cost time (min)", fontdict=label_font)

# plt.legend(prop=legendict, loc = 'upper right')
plt.legend(prop=legendict, loc = 'lower left')
plt.tight_layout()
plt.show()

# %%
t20o = [100.8, 166.1, 420.4, 649.21, 1085.2, 1267.5]
iou20o = [77.562, 83.429, 85.795, 86.360, 86.391, 86.669]

t21o = t20o[-2:]
iou21o = [76.77,90.105]

t20m = [1814, 4126.39, 7085.4, 8399.4]
iou20m = [76.3, 79.0, 79.5, 80]

t21m = [7085.4, 8399.4]
iou21m = [57.2, 70.5]

text_font = {"size":20}

# %%
legendict={'size': 20, 'weight':'bold'}
label_font = {'size': 30, 'weight':'bold'}
linewidth = 3
markersize = 30
size = 20

sns.set_theme(style="ticks")

fig = plt.figure(figsize=(12, 8))

ax = fig.add_subplot(211)

texts = []

ax.plot(t20o, iou20o, linestyle='-', color=palette[0], alpha=0.5)
ax.plot(t21o, iou21o, linestyle='--', color=palette[0], alpha=0.5)

ax.plot(t20m, iou20m, linestyle='-', color=palette[0], alpha=0.5)
ax.plot(t21m, iou21m, linestyle='--', color=palette[0], alpha=0.5)

ax.scatter(t20o, iou20o, s=400, color=palette, marker='o')
ax.scatter(t21o, iou21o, s=400, color=palette[-2:], marker='o', facecolor='none', linewidth=3)

ax.scatter(t20m, iou20m, s=400, color=palette[-4:], marker='^')
ax.scatter(t21m, iou21m, s=400, color=palette[-2:], marker='^', facecolor='none', linewidth=3)

# draw labels
ax.plot(-1000, 77, 's-', color=palette[0], label='2020', ms=15)
ax.plot(-1000, 77, 's--', color=palette[0], label='2021', alpha=0.7, ms=15, mfc="none")
ax.scatter(-1000, 77, s=700, color=palette[0], marker='s', label='baseline', alpha=0.8)
ax.scatter(-1000, 77, s=700, color=palette[1], marker='s', label='1st iteration', alpha=0.8)
ax.scatter(-1000, 77, s=700, color=palette[2], marker='s', label='2nd iteration', alpha=0.8)
ax.scatter(-1000, 77, s=700, color=palette[3], marker='s', label='3rd iteration', alpha=0.8)
ax.scatter(-1000, 77, s=700, color=palette[4], marker='s', label='4th iteration', alpha=0.8)
ax.scatter(-1000, 77, s=700, color=palette[5], marker='s', label='5th iteration', alpha=0.8)

ticks = np.arange(0, 9600, 600, dtype=np.int32)
labels = (np.arange(0, 9600, 600, dtype=np.int32)/60).astype(np.int32)
ax.set_xticks(ticks)
ax.set_xticklabels(labels, fontsize=size)

"""
text = ['baseline', 
        'iter 1',
        'iter 2',
        'iter 3',
        'iter 4',
        'iter 5',]

for x, y, t in zip(t20o, iou20o, text):
    texts.append(plt.text(x+100, y, t, ha="center", va="center", fontdict=text_font))
    
for x, y, t in zip(t21o, iou21o, text[-2:]):
    texts.append(plt.text(x+100, y, t, ha="center", va="center", fontdict=text_font))

for x, y, t in zip(t20m, iou20m, text[-4:]):
    texts.append(plt.text(x+100, y, t, ha="center", va="center", fontdict=text_font))
    
for x, y, t in zip(t21m, iou21m, text[-2:]):
    texts.append(plt.text(x+100, y, t, ha="center", va="center", fontdict=text_font))
"""

ax.text(600, 73, "Ours", ha="center", va="center", fontdict={"size":35, "weight":"bold", "alpha":0.1})
ax.text(5400, 65, "Mask RCNN", ha="center", va="center", fontdict={"size":40, "weight":"bold", "alpha":0.1})
    
adjust_text(texts, force_text=0.05)

ax.set_xlim(-100, 8600)
ax.set_ylim(55, 92)

plt.ylabel("Mean IoU (%)", fontdict=label_font)
plt.xlabel("Train cost time (min)", fontdict=label_font)

plt.yticks(fontsize=size)

# plt.legend(prop=legendict, loc = 'upper right')
plt.legend(prop=legendict, bbox_to_anchor=(1.01, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
np.arange(0, 9600, 600)
# Out:
# array([   0,  600, 1200, 1800, 2400, 3000, 3600, 4200, 4800, 5400, 6000,
#        6600, 7200, 7800, 8400, 9000])
