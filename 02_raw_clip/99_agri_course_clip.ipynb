# %%
from config import *
# Out:
# from easyric.caas_lite import TiffSpliter
# from easyric.objects import Pix4D
# from easyric.io import shp, geotiff, plot
# from easyric.calculate import geo2raw, geo2tiff
#
# import os
# import shapefile
# import numpy as np
# import matplotlib.pyplot as plt
# import pandas as pd
# import shapely
# import tifffile

# %%
from PIL import Image
from easyric.io.json import dict2json

# %%
# please refer to 01_slice/09_project2raw.ipynb
# calculate the distance
def calculate_dist2center(p4d, geo2raw_out_dict, id_name):
    dist_container = pd.DataFrame(columns=['id', 'image', 'xc', 'yc', 'dist', 'angle', #'direction', 
                                           "select", 'roi'])
    for i, c in geo2raw_out_dict.items():
        c = np.asarray(c)
        #x0, y0 = c.mean(axis=0)
        xmin, ymin = c.min(axis=0)
        xmax, ymax = c.max(axis=0)
        roi_w = xmax - xmin
        roi_h = ymax - ymin
        x0 = (xmax+xmin)/2
        y0 = (ymax+ymin)/2
                
        if roi_w > 1500 or roi_h > 1500:
            print(f"[Warning]: plot [{id_name}] on img [{i}], roi size ({roi_w},{roi_h}) exceed (1500, 1500)")
        

        x1, y1 = 0.5 * p4d.img[i].w, 0.5 * p4d.img[i].h
        d = np.sqrt((x1-x0) ** 2 + (y1 - y0) ** 2)
        
        v1 = np.asarray([x0-x1, y0-y1])
        v0 = np.asarray([0, 1])
        
        # https://blog.csdn.net/qq_32424059/article/details/100874358
        angle = calc_angle_2(v0, v1)
        """
        if angle > 45 and angle <= 135:
            direction = 'Right'
        elif angle > 135 and angle <= 225:
            direction = "Down"
        elif angle > 225 and angle <= 315:
            direction = "Left"
        else:
            direction = "Up"
        """
        
        dist_container.loc[len(dist_container)] = {"id":id_name, "image":i, "xc":x0, "yc":y0, "dist":d, 
                                                   "angle":angle, #"direction":direction,
                                                   "select":False, "roi":c}
        dist_container['dist'] = dist_container['dist'].astype(float)

    return dist_container

def calc_angle_2(v1, v2):
    '''
    支持大于180度计算
    https://www.pythonf.cn/read/131921
    '''
    r = np.arccos(np.dot(v1, v2) / (np.linalg.norm(v1, 2) * np.linalg.norm(v2, 2)))
    deg = r * 180 / np.pi

    a1 = np.array([*v1, 0])
    a2 = np.array([*v2, 0])

    a3 = np.cross(a1, a2)

    if np.sign(a3[2]) > 0:
        deg = 360 - deg

    return deg

def select_best(dist_container, strategy="min_dist"):
    if strategy == "min_dist":
        dist_container = dist_container.sort_values(by=['dist'], axis=0, ascending=True)
        dist_container = dist_container.reset_index()
    
        return dist_container.iloc[0:10, :]
    else:
        dist_container = dist_container.sort_values(by=['direction', 'dist'], axis=0, ascending=True)
        
        direct = ['Up', 'Right', 'Down', 'Left']

        for i, d in enumerate(direct):
            t_all = reverse_dist[reverse_dist.direction == d]
            t = t_all.iloc[0,:]
            ax.scatter(t.xc, t.yc, c=color[i])

# %%
#todo_pool = ["0313_m","0318_m", "0326_m", "0327_m", "0331_m", 
#             "0406_m", "0415_m", "0417_m", "0421_m", "0422_m", "0427_m", "0430_m", 
#             "0508_m"]
todo_pool = ["0318_m", "0326_m", "0406_m", "0427_m", "0430_m", "0508_m", "0512_p", "0514_p"]
csv_folder = r"C:\Users\AlienwareR4\Desktop\lecture 3 materials\broccoli"

# %%
for tp in todo_pool:
    p2 = Paths(tp)

    p4d = Pix4D(project_path=p2.pix4d_project, 
                raw_img_path=p2.raw_img, 
                project_name=p2.project_name,
                param_folder=p2.pix4d_param)
    
    shp_file = r"Y:\hwang_Pro\data\2020_tanashi_broccoli\02_GIS\rotate_grids\split_grid_2.5m.shp"
    
    process_area = shp.read_shp3d(shp_file, dsm_path=p4d.dsm_file, geotiff_proj=p4d.dsm_header['proj'], name_field="id", get_z_by="mean")
    
    plot_id = "11"
    roi = process_area[plot_id]
    
    # calculate clipped raw image sectors
    result_container = pd.DataFrame(columns=['id', 'image', 'xc', 'yc', 'dist', 'angle', 
                                              "select", 'roi'])
    img_dict = geo2raw.get_img_coords_dict(p4d, roi-p4d.offset.np, method="pmat")
    
    reverse_dist = calculate_dist2center(p4d, img_dict, id_name=plot_id)
    # filter 3 closest raw images
    selected_idx = reverse_dist.copy().sort_values(by=['dist'], axis=0, ascending=True).index[0:3]
    reverse_dist.loc[selected_idx, 'select'] = True
    result_container = pd.concat([result_container, reverse_dist])
    
    result_container['offset_x'] = round(result_container.xc - 750).astype(np.int32)
    result_container['offset_y'] = round(result_container.yc - 750).astype(np.int32)
    
    for idx, row in result_container[result_container.select].iterrows():
        original = Image.open(p4d.img[row.image].path)
        cropped = original.crop([row.offset_x, row.offset_y, row.offset_x+1500, row.offset_y+1500])

        img_name= f"{row.id}_{row.image}"

        cropped.save(f"{csv_folder}/20{tp[0:-2]}_{row.id}_{row.image}")
# Out:
# [Init][Pix4D] No ply given, however find 'broccoli_tanashi_5_20200318_mavicRGB_15m_M_group1_densified_point_cloud.ply' at current project folder
# [Init][Pix4D] No dom given, however find 'broccoli_tanashi_5_20200318_mavicRGB_15m_M_transparent_mosaic_group1.tif' at current project folder
# [Init][Pix4D] No dsm given, however find 'broccoli_tanashi_5_20200318_mavicRGB_15m_M_dsm.tif' at current project folder
# [io][geotiff][GeoCorrd] Comprehense [* 34737 geo_ascii_params (30s) b'WGS 84 / UTM zone 54N|WGS 84|'] to geotiff coordinate tag [WGS 84 / UTM zone 54N]
# [io][geotiff][GeoCorrd] Comprehense [* 34737 geo_ascii_params (30s) b'WGS 84 / UTM zone 54N|WGS 84|'] to geotiff coordinate tag [WGS 84 / UTM zone 54N]
# [io][geotiff][GeoCorrd] Comprehense [* 34737 geo_ascii_params (30s) b'WGS 84 / UTM zone 54N|WGS 84|'] to geotiff coordinate tag [WGS 84 / UTM zone 54N]
# [io][shp][fields] Shp fields: {'id': 0, 'left': 1, 'top': 2, 'right': 3, 'bottom': 4}
# [io][shp][proj] find ESRI projection file Y:\hwang_Pro\data\2020_tanashi_broccoli\02_GIS\rotate_grids\split_grid_2.5m.prj, and successfully obtain projection cartesian
# [Warning]: plot [11] on img [DJI_0587.JPG], roi size (4450.357164131647,1407.1858599555758) exceed (1500, 1500)
# [Warning]: plot [11] on img [DJI_0588.JPG], roi size (4755.396940894244,1223.000379900975) exceed (1500, 1500)
# [Init][Pix4D] No ply given, however find 'broccoli_tanashi_5_20200326_mavicRGB_15m_M_group1_densified_point_cloud.ply' at current project folder
# [Init][Pix4D] No dom given, however find 'broccoli_tanashi_5_20200326_mavicRGB_15m_M_transparent_mosaic_group1.tif' at current project folder
# [Init][Pix4D] No dsm given, however find 'broccoli_tanashi_5_20200326_mavicRGB_15m_M_dsm.tif' at current project folder
# [io][geotiff][GeoCorrd] Comprehense [* 34737 geo_ascii_params (30s) b'WGS 84 / UTM zone 54N|WGS 84|'] to geotiff coordinate tag [WGS 84 / UTM zone 54N]
# [io][geotiff][GeoCorrd] Comprehense [* 34737 geo_ascii_params (30s) b'WGS 84 / UTM zone 54N|WGS 84|'] to geotiff coordinate tag [WGS 84 / UTM zone 54N]
# [io][geotiff][GeoCorrd] Comprehense [* 34737 geo_ascii_params (30s) b'WGS 84 / UTM zone 54N|WGS 84|'] to geotiff coordinate tag [WGS 84 / UTM zone 54N]
# [io][shp][fields] Shp fields: {'id': 0, 'left': 1, 'top': 2, 'right': 3, 'bottom': 4}
# [io][shp][proj] find ESRI projection file Y:\hwang_Pro\data\2020_tanashi_broccoli\02_GIS\rotate_grids\split_grid_2.5m.prj, and successfully obtain projection cartesian
# [Warning]: plot [11] on img [DJI_0031.JPG], roi size (4192.579774906961,2781.7223920513097) exceed (1500, 1500)
# [Warning]: plot [11] on img [DJI_0032.JPG], roi size (3443.1076669141003,1996.4552412316666) exceed (1500, 1500)
# [Warning]: plot [11] on img [DJI_0085.JPG], roi size (3179.4010921519875,3263.6483672635622) exceed (1500, 1500)
# [Init][Pix4D] No ply given, however find 'broccoli_tanashi_5_20200406_mavicRGB_15m_M_group1_densified_point_cloud.ply' at current project folder
# [Init][Pix4D] No dom given, however find 'broccoli_tanashi_5_20200406_mavicRGB_15m_M_transparent_mosaic_group1.tif' at current project folder
# [Init][Pix4D] No dsm given, however find 'broccoli_tanashi_5_20200406_mavicRGB_15m_M_dsm.tif' at current project folder
# [io][geotiff][GeoCorrd] Comprehense [* 34737 geo_ascii_params (30s) b'WGS 84 / UTM zone 54N|WGS 84|'] to geotiff coordinate tag [WGS 84 / UTM zone 54N]
# [io][geotiff][GeoCorrd] Comprehense [* 34737 geo_ascii_params (30s) b'WGS 84 / UTM zone 54N|WGS 84|'] to geotiff coordinate tag [WGS 84 / UTM zone 54N]
# [io][geotiff][GeoCorrd] Comprehense [* 34737 geo_ascii_params (30s) b'WGS 84 / UTM zone 54N|WGS 84|'] to geotiff coordinate tag [WGS 84 / UTM zone 54N]
# [io][shp][fields] Shp fields: {'id': 0, 'left': 1, 'top': 2, 'right': 3, 'bottom': 4}
# [io][shp][proj] find ESRI projection file Y:\hwang_Pro\data\2020_tanashi_broccoli\02_GIS\rotate_grids\split_grid_2.5m.prj, and successfully obtain projection cartesian
# [Warning]: plot [11] on img [DJI_0448.JPG], roi size (4671.961950449097,1963.509658568957) exceed (1500, 1500)
# [Warning]: plot [11] on img [DJI_0449.JPG], roi size (4364.914959403506,1485.7388530535927) exceed (1500, 1500)
# [Warning]: plot [11] on img [DJI_0495.JPG], roi size (4139.057815687995,3354.5256638192022) exceed (1500, 1500)
# [Init][Pix4D] No ply given, however find 'broccoli_tanashi_5_20200427_mavicRGB_15m_M_group1_densified_point_cloud.ply' at current project folder
# [Init][Pix4D] No dom given, however find 'broccoli_tanashi_5_20200427_mavicRGB_15m_M_transparent_mosaic_group1.tif' at current project folder
# [Init][Pix4D] No dsm given, however find 'broccoli_tanashi_5_20200427_mavicRGB_15m_M_dsm.tif' at current project folder
# [io][geotiff][GeoCorrd] Comprehense [* 34737 geo_ascii_params (30s) b'WGS 84 / UTM zone 54N|WGS 84|'] to geotiff coordinate tag [WGS 84 / UTM zone 54N]
# [io][geotiff][GeoCorrd] Comprehense [* 34737 geo_ascii_params (30s) b'WGS 84 / UTM zone 54N|WGS 84|'] to geotiff coordinate tag [WGS 84 / UTM zone 54N]
# [io][geotiff][GeoCorrd] Comprehense [* 34737 geo_ascii_params (30s) b'WGS 84 / UTM zone 54N|WGS 84|'] to geotiff coordinate tag [WGS 84 / UTM zone 54N]
# [io][shp][fields] Shp fields: {'id': 0, 'left': 1, 'top': 2, 'right': 3, 'bottom': 4}
# [io][shp][proj] find ESRI projection file Y:\hwang_Pro\data\2020_tanashi_broccoli\02_GIS\rotate_grids\split_grid_2.5m.prj, and successfully obtain projection cartesian
# [Warning]: plot [11] on img [DJI_0438.JPG], roi size (4389.0596564607295,2623.373196796886) exceed (1500, 1500)
# [Init][Pix4D] No ply given, however find 'broccoli_tanashi_5_20200430_mavicRGB_15m_M_group1_densified_point_cloud.ply' at current project folder
# [Init][Pix4D] No dom given, however find 'broccoli_tanashi_5_20200430_mavicRGB_15m_M_transparent_mosaic_group1.tif' at current project folder
# [Init][Pix4D] No dsm given, however find 'broccoli_tanashi_5_20200430_mavicRGB_15m_M_dsm.tif' at current project folder
# [io][geotiff][GeoCorrd] Comprehense [* 34737 geo_ascii_params (30s) b'WGS 84 / UTM zone 54N|WGS 84|'] to geotiff coordinate tag [WGS 84 / UTM zone 54N]
# [io][geotiff][GeoCorrd] Comprehense [* 34737 geo_ascii_params (30s) b'WGS 84 / UTM zone 54N|WGS 84|'] to geotiff coordinate tag [WGS 84 / UTM zone 54N]
# [io][geotiff][GeoCorrd] Comprehense [* 34737 geo_ascii_params (30s) b'WGS 84 / UTM zone 54N|WGS 84|'] to geotiff coordinate tag [WGS 84 / UTM zone 54N]
# [io][shp][fields] Shp fields: {'id': 0, 'left': 1, 'top': 2, 'right': 3, 'bottom': 4}
# [io][shp][proj] find ESRI projection file Y:\hwang_Pro\data\2020_tanashi_broccoli\02_GIS\rotate_grids\split_grid_2.5m.prj, and successfully obtain projection cartesian
# [Warning]: plot [11] on img [DJI_0183.JPG], roi size (4872.484422695734,2245.224779343125) exceed (1500, 1500)
# [Init][Pix4D] No ply given, however find 'broccoli_tanashi_5_20200508_mavicRGB_15m_M_group1_densified_point_cloud.ply' at current project folder
# [Init][Pix4D] No dom given, however find 'broccoli_tanashi_5_20200508_mavicRGB_15m_M_transparent_mosaic_group1.tif' at current project folder
# [Init][Pix4D] No dsm given, however find 'broccoli_tanashi_5_20200508_mavicRGB_15m_M_dsm.tif' at current project folder
# [io][geotiff][GeoCorrd] Comprehense [* 34737 geo_ascii_params (30s) b'WGS 84 / UTM zone 54N|WGS 84|'] to geotiff coordinate tag [WGS 84 / UTM zone 54N]
# [io][geotiff][GeoCorrd] Comprehense [* 34737 geo_ascii_params (30s) b'WGS 84 / UTM zone 54N|WGS 84|'] to geotiff coordinate tag [WGS 84 / UTM zone 54N]
# [io][geotiff][GeoCorrd] Comprehense [* 34737 geo_ascii_params (30s) b'WGS 84 / UTM zone 54N|WGS 84|'] to geotiff coordinate tag [WGS 84 / UTM zone 54N]
# [io][shp][fields] Shp fields: {'id': 0, 'left': 1, 'top': 2, 'right': 3, 'bottom': 4}
# [io][shp][proj] find ESRI projection file Y:\hwang_Pro\data\2020_tanashi_broccoli\02_GIS\rotate_grids\split_grid_2.5m.prj, and successfully obtain projection cartesian
# [Warning]: plot [11] on img [DJI_0183.JPG], roi size (4753.331878594516,2160.2700715049787) exceed (1500, 1500)
# [Init][Pix4D] No ply given, however find 'broccoli_tanashi_5_20200512_P4M_10m_group1_densified_point_cloud.ply' at current project folder
# [Init][Pix4D] No dom given, however find 'broccoli_tanashi_5_20200512_P4M_10m_transparent_mosaic_group1.tif' at current project folder
# [Init][Pix4D] No dsm given, however find 'broccoli_tanashi_5_20200512_P4M_10m_dsm.tif' at current project folder
# [io][geotiff][GeoCorrd] Comprehense [* 34737 geo_ascii_params (30s) b'WGS 84 / UTM zone 54N|WGS 84|'] to geotiff coordinate tag [WGS 84 / UTM zone 54N]
# [io][geotiff][GeoCorrd] Comprehense [* 34737 geo_ascii_params (30s) b'WGS 84 / UTM zone 54N|WGS 84|'] to geotiff coordinate tag [WGS 84 / UTM zone 54N]
# [io][geotiff][GeoCorrd] Comprehense [* 34737 geo_ascii_params (30s) b'WGS 84 / UTM zone 54N|WGS 84|'] to geotiff coordinate tag [WGS 84 / UTM zone 54N]
# [io][shp][fields] Shp fields: {'id': 0, 'left': 1, 'top': 2, 'right': 3, 'bottom': 4}
# [io][shp][proj] find ESRI projection file Y:\hwang_Pro\data\2020_tanashi_broccoli\02_GIS\rotate_grids\split_grid_2.5m.prj, and successfully obtain projection cartesian
# [Warning]: plot [11] on img [DJI_0591.JPG], roi size (1535.6328189031592,1534.998869200765) exceed (1500, 1500)
# [Warning]: plot [11] on img [DJI_0592.JPG], roi size (1552.5010493413374,1541.3448681016914) exceed (1500, 1500)
# [Warning]: plot [11] on img [DJI_0621.JPG], roi size (1500.329285487955,1504.7033158836775) exceed (1500, 1500)
# [Init][Pix4D] No ply given, however find 'broccoli_tanashi_5_20200514_P4M_10m_group1_densified_point_cloud.ply' at current project folder
# [Init][Pix4D] No dom given, however find 'broccoli_tanashi_5_20200514_P4M_10m_transparent_mosaic_group1.tif' at current project folder
# [Init][Pix4D] No dsm given, however find 'broccoli_tanashi_5_20200514_P4M_10m_dsm.tif' at current project folder
# [io][geotiff][GeoCorrd] Comprehense [* 34737 geo_ascii_params (30s) b'WGS 84 / UTM zone 54N|WGS 84|'] to geotiff coordinate tag [WGS 84 / UTM zone 54N]
# [io][geotiff][GeoCorrd] Comprehense [* 34737 geo_ascii_params (30s) b'WGS 84 / UTM zone 54N|WGS 84|'] to geotiff coordinate tag [WGS 84 / UTM zone 54N]
# [io][geotiff][GeoCorrd] Comprehense [* 34737 geo_ascii_params (30s) b'WGS 84 / UTM zone 54N|WGS 84|'] to geotiff coordinate tag [WGS 84 / UTM zone 54N]
# [io][shp][fields] Shp fields: {'id': 0, 'left': 1, 'top': 2, 'right': 3, 'bottom': 4}
# [io][shp][proj] find ESRI projection file Y:\hwang_Pro\data\2020_tanashi_broccoli\02_GIS\rotate_grids\split_grid_2.5m.prj, and successfully obtain projection cartesian

# %%
result_container
# Out:
# Empty DataFrame
# Columns: [id, image, xc, yc, dist, angle, select, roi, offset_x, offset_y]
# Index: []
